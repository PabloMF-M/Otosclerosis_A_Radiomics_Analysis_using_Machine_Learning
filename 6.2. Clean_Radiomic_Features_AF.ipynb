# %% [markdown]
# # <center>**RADIOMICS EXTRACTION - Clean Radiomic Features - AF**</center>
#
# *Repetition of Step 7 for Antefenestram Cleaning of Radiomic features.*
#
# (*Step 7*)

# %% [markdown]
# ## **Radiomics Workflow:**
#
#   **1. Download** DICOM images and convert to **NRRD.**
#
#   **2.** Perform **target segmentations** and save in **NRRD.**
#
#   **3.** Perform a **first Radiomic Feature** ***Dummy*** **Extraction,** to:
#
#   - Detect **erros in segmentations**: only one dimension, no label 1, only one segmented voxel...
#   - Analyze **bin wdith**.
#
#
#   **4. Analyze** and **correct mask errors.**
#
#   **5. Adjust binwith.**
#    - **Tune featureextractor param file.**
#
#
#   **6.** Perform **final Radiomic Feature Extraction.**
#
#   **7. Clean Radiomic Features.**
#
#   **8. Merge** with **labels** and **clinical data.**
#
#   **9. Descriptive Statistics.**
#
#   **10. Inferential Statistics.**
#
#   **11. Machine Learning.**

# %% [markdown]
# ## **CLEAN RADIOMIC FEATURES DATAFRAME**

# %% [markdown]
# This notebook has been designed to **clean the dataframes** that contain the **radiomic features extracted** in the previous step.
#
# 0.   Environment **configuration**.
# 1.   **Load data.**
# 2.   **Filter Radiomic Features** from extraction data.
# 3.   Check **datatypes.**
# 4.   Identify and remove **non-useful variables.**
#        * 4.1. Columns with too much **<code>NaN</code>**.
#        * 4.2. Columns with **low variance** - **low number of unique values** (only one different value...).
# 5.   **Dimensionality Reduction.**
#        * 5.1. **Correlated** variables.
# 6. **Adapt dataframe to merge** with clinical data and labels.
# 7. **Save Radiomic features cleaned.**

# %%
# Install libraries
#pip install openpyxl

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %% [markdown]
# ### **0. Environment configuration**

# %% [markdown]
# #### Set the working directory

# %%
# Set working directory
wd = '/Users/pablomenendezfernandez-miranda/Proyecto Otosclerosis/'
os.chdir(wd)

print(f'Directorio actual: {os.getcwd()}')

# Check directory files
print(f'Directory files: {os.listdir(wd)}')
# Out:
# Directorio actual: /Users/pablomenendezfernandez-miranda/Proyecto Otosclerosis
# Directory files: ['Tables', 'Databases', '.DS_Store', '6.1.png', 'CITATION.cff', '6.2.png', 'Episodes', '6.3.png', 'Slides', 'Figures', 'LICENSE.txt', 'Comité de ética', 'Notebooks']

# %% [markdown]
# #### Mount Drive (if executed on Google Colab)

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ### **1. Load data**

# %%
# Load pandas dataframe
df_dir= 'Databases/4_2_df_radiomics_AF_tuned_final_features.csv'
df= pd.read_csv(df_dir, na_values='nan')

print(df.shape)
df.head(4)
# Out:
# (99, 2054)
#   Image_Segmentation diagnostics_Versions_PyRadiomics  \
# 0   EPI_0001_AF.nrrd          3.1.0a2.post14+gaab3c6f
# 1   EPI_0002_AF.nrrd          3.1.0a2.post14+gaab3c6f
# 2   EPI_0003_AF.nrrd          3.1.0a2.post14+gaab3c6f
# 3   EPI_0004_AF.nrrd          3.1.0a2.post14+gaab3c6f
#
#   diagnostics_Versions_Numpy diagnostics_Versions_SimpleITK  \
# 0                     1.26.4                          2.4.0
# 1                     1.26.4                          2.4.0
# 2                     1.26.4                          2.4.0
# 3                     1.26.4                          2.4.0
#
#   diagnostics_Versions_PyWavelet diagnostics_Versions_Python  \
# 0                          1.7.0                      3.12.4
# 1                          1.7.0                      3.12.4
# 2                          1.7.0                      3.12.4
# 3                          1.7.0                      3.12.4
#
#                   diagnostics_Configuration_Settings  \
# 0  {'minimumROIDimensions': 1, 'minimumROISize': ...
# 1  {'minimumROIDimensions': 1, 'minimumROISize': ...
# 2  {'minimumROIDimensions': 1, 'minimumROISize': ...
# 3  {'minimumROIDimensions': 1, 'minimumROISize': ...
#
#          diagnostics_Configuration_EnabledImageTypes  \
# 0  {'Original': {'binWidth': 35.93}, 'Square': {'...
# 1  {'Original': {'binWidth': 35.93}, 'Square': {'...
# 2  {'Original': {'binWidth': 35.93}, 'Square': {'...
# 3  {'Original': {'binWidth': 35.93}, 'Square': {'...
#
#             diagnostics_Image-original_Hash  \
# 0  1310b8441367f403dccd0241fde06dd70966c56a
# 1  64fb22f54e86a46714e45ec0a26705a81f50b639
# 2  c37a6f6b17a1a89cd5f06d640fb8e33dc6219c6e
# 3  5dce836924eb76ab17bb61896784da9f4cd31cbd
#
#   diagnostics_Image-original_Dimensionality  ...  \
# 0                                        3D  ...
# 1                                        3D  ...
# 2                                        3D  ...
# 3                                        3D  ...
#
#   lbp-3D-k_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                         15.010085
# 1                                         11.243687
# 2                                         17.345118
# 3                                         12.318930
#
#   lbp-3D-k_gldm_LowGrayLevelEmphasis  lbp-3D-k_gldm_SmallDependenceEmphasis  \
# 0                           0.606239                               0.192961
# 1                           0.380051                               0.104544
# 2                           0.491582                               0.076806
# 3                           0.467078                               0.103222
#
#    lbp-3D-k_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           1.769625
# 1                                           0.546965
# 2                                           0.243797
# 3                                           0.495049
#
#    lbp-3D-k_gldm_SmallDependenceLowGrayLevelEmphasis lbp-3D-k_ngtdm_Busyness  \
# 0                                           0.078111                1.515360
# 1                                           0.044444                0.508064
# 2                                           0.051893                1.118533
# 3                                           0.046418                1.046149
#
#   lbp-3D-k_ngtdm_Coarseness lbp-3D-k_ngtdm_Complexity lbp-3D-k_ngtdm_Contrast  \
# 0                  0.164977                  5.904967                0.093878
# 1                  0.349207                  1.050969                0.023217
# 2                  0.216933                  1.293046                0.042011
# 3                  0.195522                  1.568187                0.040570
#
#    lbp-3D-k_ngtdm_Strength
# 0                 1.871021
# 1                 0.730429
# 2                 0.488941
# 3                 0.485882
#
# [4 rows x 2054 columns]

# %% [markdown]
# ### **2. Filter Radiomic Features from extraction data**

# %%
# Identify extraction data columns
idx_to_delete= []
idx= -1
for key, value in df.dtypes.items():
  idx= idx+1
  if (key.startswith('diagnostics_')) or (value != 'float64'):
    print(f'{idx}_{key}: {value}')
    idx_to_delete.append(idx)
# Out:
# 0_Image_Segmentation: object
# 1_diagnostics_Versions_PyRadiomics: object
# 2_diagnostics_Versions_Numpy: object
# 3_diagnostics_Versions_SimpleITK: object
# 4_diagnostics_Versions_PyWavelet: object
# 5_diagnostics_Versions_Python: object
# 6_diagnostics_Configuration_Settings: object
# 7_diagnostics_Configuration_EnabledImageTypes: object
# 8_diagnostics_Image-original_Hash: object
# 9_diagnostics_Image-original_Dimensionality: object
# 10_diagnostics_Image-original_Spacing: object
# 11_diagnostics_Image-original_Size: object
# 12_diagnostics_Image-original_Mean: float64
# 13_diagnostics_Image-original_Minimum: float64
# 14_diagnostics_Image-original_Maximum: float64
# 15_diagnostics_Mask-original_Hash: object
# 16_diagnostics_Mask-original_Spacing: object
# 17_diagnostics_Mask-original_Size: object
# 18_diagnostics_Mask-original_BoundingBox: object
# 19_diagnostics_Mask-original_VoxelNum: int64
# 20_diagnostics_Mask-original_VolumeNum: int64
# 21_diagnostics_Mask-original_CenterOfMassIndex: object
# 22_diagnostics_Mask-original_CenterOfMass: object
# 23_diagnostics_Image-interpolated_Spacing: object
# 24_diagnostics_Image-interpolated_Size: object
# 25_diagnostics_Image-interpolated_Mean: float64
# 26_diagnostics_Image-interpolated_Minimum: float64
# 27_diagnostics_Image-interpolated_Maximum: float64
# 28_diagnostics_Mask-interpolated_Spacing: object
# 29_diagnostics_Mask-interpolated_Size: object
# 30_diagnostics_Mask-interpolated_BoundingBox: object
# 31_diagnostics_Mask-interpolated_VoxelNum: int64
# 32_diagnostics_Mask-interpolated_VolumeNum: int64
# 33_diagnostics_Mask-interpolated_CenterOfMassIndex: object
# 34_diagnostics_Mask-interpolated_CenterOfMass: object
# 35_diagnostics_Mask-interpolated_Mean: float64
# 36_diagnostics_Mask-interpolated_Minimum: float64
# 37_diagnostics_Mask-interpolated_Maximum: float64

# %%
df_features= df.drop(df.columns[idx_to_delete[1:]], axis = 1)
df_features.head(4)
# Out:
#   Image_Segmentation  original_shape_Elongation  original_shape_Flatness  \
# 0   EPI_0001_AF.nrrd                   0.769875                 0.710120
# 1   EPI_0002_AF.nrrd                   0.738604                 0.613252
# 2   EPI_0003_AF.nrrd                   0.650602                 0.590866
# 3   EPI_0004_AF.nrrd                   0.652408                 0.586433
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        3.023389                        4.257578
# 1                        2.815211                        4.590630
# 2                        3.140533                        5.315134
# 3                        3.097962                        5.282717
#
#    original_shape_Maximum2DDiameterColumn  \
# 0                                5.099020
# 1                                4.472136
# 2                                5.385165
# 3                                5.385165
#
#    original_shape_Maximum2DDiameterRow  original_shape_Maximum2DDiameterSlice  \
# 0                             4.123106                               5.099020
# 1                             3.605551                               4.472136
# 2                             4.472136                               5.385165
# 3                             4.123106                               5.099020
#
#    original_shape_Maximum3DDiameter  original_shape_MeshVolume  ...  \
# 0                          5.196152                  21.541667  ...
# 1                          4.898979                  17.375000  ...
# 2                          5.477226                  28.458333  ...
# 3                          5.477226                  21.875000  ...
#
#    lbp-3D-k_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                          15.010085
# 1                                          11.243687
# 2                                          17.345118
# 3                                          12.318930
#
#    lbp-3D-k_gldm_LowGrayLevelEmphasis  lbp-3D-k_gldm_SmallDependenceEmphasis  \
# 0                            0.606239                               0.192961
# 1                            0.380051                               0.104544
# 2                            0.491582                               0.076806
# 3                            0.467078                               0.103222
#
#    lbp-3D-k_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           1.769625
# 1                                           0.546965
# 2                                           0.243797
# 3                                           0.495049
#
#    lbp-3D-k_gldm_SmallDependenceLowGrayLevelEmphasis  lbp-3D-k_ngtdm_Busyness  \
# 0                                           0.078111                 1.515360
# 1                                           0.044444                 0.508064
# 2                                           0.051893                 1.118533
# 3                                           0.046418                 1.046149
#
#    lbp-3D-k_ngtdm_Coarseness  lbp-3D-k_ngtdm_Complexity  \
# 0                   0.164977                   5.904967
# 1                   0.349207                   1.050969
# 2                   0.216933                   1.293046
# 3                   0.195522                   1.568187
#
#    lbp-3D-k_ngtdm_Contrast  lbp-3D-k_ngtdm_Strength
# 0                 0.093878                 1.871021
# 1                 0.023217                 0.730429
# 2                 0.042011                 0.488941
# 3                 0.040570                 0.485882
#
# [4 rows x 2017 columns]

# %% [markdown]
# ### **3. Check datatypes**

# %%
pd.DataFrame(df_features.dtypes.value_counts())
# Out:
#          count
# float64   2016
# object       1

# %% [markdown]
# ### **4. Identify and remove non-useful variables.**

# %% [markdown]
# * 4.1. Columns with too much **<code>NaN</code>**.
# * 4.2. Columns with **low variance** - **low number of unique values** (only one different value...).

# %%
# PRINT FULL DATAFRAME

def df_show_full(show):
  if show == True:
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
  if show == False:
    pd.reset_option('display.max_rows')
    pd.reset_option('display.max_columns')

# %% [markdown]
# #### **4.1. Columns with too much <code>NaN</code>**

# %%
df_show_full(True)

n_nan= 12
null_values= df_features.isnull().sum()
pd.DataFrame(null_values[null_values > n_nan].sort_values(ascending=False))
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
# Delete columns with more than 40% of NaN values
nan_threshold = 0.4 * len(df_features)
df_features_nonan= df_features.dropna(axis=1, thresh=nan_threshold, inplace=False)

print(f'Dataframe shape pre-processing: {df_features.shape}')
print(f'Dataframe shape post-processing: {df_features_nonan.shape}')
# Out:
# Dataframe shape pre-processing: (99, 2017)
# Dataframe shape post-processing: (99, 2017)

# %% [markdown]
# #### **4.2. Columns with low variance - low number of unique values (only one different value...)**

# %%
# Remove variables with a very low variance (2%)
var_threshold= 0.02

# Exclude fisrt column (object type)
object_cols= ['Image_Segmentation']
df_features_vars= df_features_nonan.select_dtypes(include=[float, int]).var()

# Select features with more than var_threshold variance
features_to_preserve= list(df_features_vars[df_features_vars > var_threshold].index)
df_features_filter= df_features_nonan[object_cols + features_to_preserve]

# Removed variables
removed_lowvar= list(df_features_vars[df_features_vars <= var_threshold].index)

# Print report
print(f'{len(removed_lowvar)} variables removed (variance < {var_threshold})')
print(f'\nDataframe shape pre-processing: {df_features_nonan.shape}')
print(f'Dataframe shape post-processing: {df_features_filter.shape}')
print('')
print(f'\nRemoved variables (variance < {var_threshold}): {removed_lowvar}')
# Out:
# 742 variables removed (variance < 0.02)
#
# Dataframe shape pre-processing: (99, 2017)
# Dataframe shape post-processing: (99, 1275)
#
#
# Removed variables (variance < 0.02): ['original_shape_Elongation', 'original_shape_Flatness', 'original_shape_Sphericity', 'original_firstorder_Uniformity', 'original_glcm_Correlation', 'original_glcm_JointEnergy', 'original_glcm_Imc1', 'original_glcm_Imc2', 'original_glcm_Idm', 'original_glcm_Idmn', 'original_glcm_Id', 'original_glcm_Idn', 'original_glcm_InverseVariance', 'original_glcm_MaximumProbability', 'original_glrlm_GrayLevelNonUniformityNormalized', 'original_glrlm_LongRunEmphasis', 'original_glrlm_LongRunLowGrayLevelEmphasis', 'original_glrlm_LowGrayLevelRunEmphasis', 'original_glrlm_RunLengthNonUniformityNormalized', 'original_glrlm_RunPercentage', 'original_glrlm_RunVariance', 'original_glrlm_ShortRunEmphasis', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'original_glszm_GrayLevelNonUniformityNormalized', 'original_glszm_LargeAreaLowGrayLevelEmphasis', 'original_glszm_LowGrayLevelZoneEmphasis', 'original_glszm_SizeZoneNonUniformityNormalized', 'original_glszm_SmallAreaEmphasis', 'original_glszm_SmallAreaLowGrayLevelEmphasis', 'original_glszm_ZonePercentage', 'original_glszm_ZoneVariance', 'original_gldm_LargeDependenceLowGrayLevelEmphasis', 'original_gldm_LowGrayLevelEmphasis', 'original_gldm_SmallDependenceEmphasis', 'original_gldm_SmallDependenceLowGrayLevelEmphasis', 'original_ngtdm_Busyness', 'original_ngtdm_Coarseness', 'square_firstorder_Uniformity', 'square_glcm_Correlation', 'square_glcm_JointEnergy', 'square_glcm_Imc1', 'square_glcm_Imc2', 'square_glcm_Idm', 'square_glcm_Idmn', 'square_glcm_Id', 'square_glcm_Idn', 'square_glcm_InverseVariance', 'square_glcm_MaximumProbability', 'square_glrlm_GrayLevelNonUniformityNormalized', 'square_glrlm_LongRunEmphasis', 'square_glrlm_LongRunLowGrayLevelEmphasis', 'square_glrlm_LowGrayLevelRunEmphasis', 'square_glrlm_RunLengthNonUniformityNormalized', 'square_glrlm_RunPercentage', 'square_glrlm_RunVariance', 'square_glrlm_ShortRunEmphasis', 'square_glrlm_ShortRunLowGrayLevelEmphasis', 'square_glszm_GrayLevelNonUniformityNormalized', 'square_glszm_LargeAreaLowGrayLevelEmphasis', 'square_glszm_LowGrayLevelZoneEmphasis', 'square_glszm_SizeZoneNonUniformityNormalized', 'square_glszm_SmallAreaEmphasis', 'square_glszm_SmallAreaLowGrayLevelEmphasis', 'square_glszm_ZonePercentage', 'square_gldm_LargeDependenceLowGrayLevelEmphasis', 'square_gldm_LowGrayLevelEmphasis', 'square_gldm_SmallDependenceEmphasis', 'square_gldm_SmallDependenceLowGrayLevelEmphasis', 'square_ngtdm_Busyness', 'square_ngtdm_Coarseness', 'squareroot_firstorder_Uniformity', 'squareroot_glcm_Correlation', 'squareroot_glcm_JointEnergy', 'squareroot_glcm_Imc1', 'squareroot_glcm_Imc2', 'squareroot_glcm_Idm', 'squareroot_glcm_Idmn', 'squareroot_glcm_Id', 'squareroot_glcm_Idn', 'squareroot_glcm_InverseVariance', 'squareroot_glcm_MaximumProbability', 'squareroot_glrlm_GrayLevelNonUniformityNormalized', 'squareroot_glrlm_LongRunEmphasis', 'squareroot_glrlm_LongRunLowGrayLevelEmphasis', 'squareroot_glrlm_LowGrayLevelRunEmphasis', 'squareroot_glrlm_RunLengthNonUniformityNormalized', 'squareroot_glrlm_RunPercentage', 'squareroot_glrlm_RunVariance', 'squareroot_glrlm_ShortRunEmphasis', 'squareroot_glrlm_ShortRunLowGrayLevelEmphasis', 'squareroot_glszm_GrayLevelNonUniformityNormalized', 'squareroot_glszm_LargeAreaLowGrayLevelEmphasis', 'squareroot_glszm_LowGrayLevelZoneEmphasis', 'squareroot_glszm_SizeZoneNonUniformityNormalized', 'squareroot_glszm_SmallAreaEmphasis', 'squareroot_glszm_SmallAreaLowGrayLevelEmphasis', 'squareroot_glszm_ZonePercentage', 'squareroot_gldm_LargeDependenceLowGrayLevelEmphasis', 'squareroot_gldm_LowGrayLevelEmphasis', 'squareroot_gldm_SmallDependenceEmphasis', 'squareroot_gldm_SmallDependenceLowGrayLevelEmphasis', 'squareroot_ngtdm_Busyness', 'squareroot_ngtdm_Coarseness', 'logarithm_firstorder_Uniformity', 'logarithm_glcm_Correlation', 'logarithm_glcm_JointEnergy', 'logarithm_glcm_Imc1', 'logarithm_glcm_Imc2', 'logarithm_glcm_Idm', 'logarithm_glcm_Idmn', 'logarithm_glcm_Id', 'logarithm_glcm_Id ...

# %% [markdown]
# ### **5. Dimensionality Reduction**

# %% [markdown]
# * 5.1. **Correlated** variables.

# %% [markdown]
# #### **5.1. Correlated columns**

# %%
# Remove one of each pair of highly correlated variables
corr_test= 'pearson'
#corr_test= 'spearman'
corr_threshold= 0.90

# Exclude fisrt column (object type) - use df_numeric
object_cols= ['Image_Segmentation']
df_features_numeric= df_features_filter.select_dtypes(include=[float, int])

# Compute corr matrix and select the upper hemimatrix (symetrical)
corr_matrix= df_features_numeric.corr(method='pearson').abs()
upper_matrix = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Select highly correlated vars
corr_vars= [column for column in upper_matrix.columns if any(upper_matrix[column] > corr_threshold)]

# Remove higly correlated variables - the second of each corr_pair (drop list adds columns, not rows)
df_features_decorr= df_features_filter.drop(columns=corr_vars, inplace=False)

# Print report
print(f'{len(corr_vars)} removed variables (corr_{corr_test} > {corr_threshold})')
print(f'\nDataframe shape pre-processing: {df_features_filter.shape}')
print(f'Dataframe shape post-processing: {df_features_decorr.shape}')
print(f'\nRemoved variables (corr_{corr_test} > {corr_threshold}): {corr_vars}')
# Out:
# 796 removed variables (corr_pearson > 0.9)
#
# Dataframe shape pre-processing: (99, 1275)
# Dataframe shape post-processing: (99, 479)
#
# Removed variables (corr_pearson > 0.9): ['original_shape_SurfaceArea', 'original_shape_VoxelVolume', 'original_firstorder_Median', 'original_firstorder_Range', 'original_firstorder_RobustMeanAbsoluteDeviation', 'original_firstorder_RootMeanSquared', 'original_firstorder_TotalEnergy', 'original_firstorder_Variance', 'original_glcm_JointAverage', 'original_glcm_ClusterTendency', 'original_glcm_DifferenceAverage', 'original_glcm_DifferenceEntropy', 'original_glcm_DifferenceVariance', 'original_glcm_JointEntropy', 'original_glcm_SumEntropy', 'original_glcm_SumSquares', 'original_glrlm_GrayLevelVariance', 'original_glrlm_HighGrayLevelRunEmphasis', 'original_glrlm_LongRunHighGrayLevelEmphasis', 'original_glrlm_RunEntropy', 'original_glrlm_RunLengthNonUniformity', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'original_glszm_GrayLevelVariance', 'original_glszm_HighGrayLevelZoneEmphasis', 'original_glszm_LargeAreaHighGrayLevelEmphasis', 'original_glszm_SmallAreaHighGrayLevelEmphasis', 'original_glszm_ZoneEntropy', 'original_gldm_DependenceEntropy', 'original_gldm_DependenceNonUniformity', 'original_gldm_GrayLevelNonUniformity', 'original_gldm_GrayLevelVariance', 'original_gldm_HighGrayLevelEmphasis', 'original_gldm_LargeDependenceEmphasis', 'original_gldm_LargeDependenceHighGrayLevelEmphasis', 'original_gldm_SmallDependenceHighGrayLevelEmphasis', 'square_firstorder_10Percentile', 'square_firstorder_90Percentile', 'square_firstorder_Energy', 'square_firstorder_InterquartileRange', 'square_firstorder_Maximum', 'square_firstorder_MeanAbsoluteDeviation', 'square_firstorder_Mean', 'square_firstorder_Median', 'square_firstorder_RobustMeanAbsoluteDeviation', 'square_firstorder_RootMeanSquared', 'square_firstorder_TotalEnergy', 'square_firstorder_Variance', 'square_glcm_JointAverage', 'square_glcm_ClusterTendency', 'square_glcm_DifferenceAverage', 'square_glcm_DifferenceEntropy', 'square_glcm_JointEntropy', 'square_glcm_SumEntropy', 'square_glcm_SumSquares', 'square_glrlm_GrayLevelVariance', 'square_glrlm_HighGrayLevelRunEmphasis', 'square_glrlm_LongRunHighGrayLevelEmphasis', 'square_glrlm_RunEntropy', 'square_glrlm_RunLengthNonUniformity', 'square_glrlm_ShortRunHighGrayLevelEmphasis', 'square_glszm_GrayLevelVariance', 'square_glszm_HighGrayLevelZoneEmphasis', 'square_glszm_SmallAreaHighGrayLevelEmphasis', 'square_glszm_ZoneEntropy', 'square_glszm_ZoneVariance', 'square_gldm_DependenceEntropy', 'square_gldm_DependenceNonUniformity', 'square_gldm_GrayLevelNonUniformity', 'square_gldm_GrayLevelVariance', 'square_gldm_HighGrayLevelEmphasis', 'square_gldm_LargeDependenceEmphasis', 'square_gldm_LargeDependenceHighGrayLevelEmphasis', 'square_gldm_SmallDependenceHighGrayLevelEmphasis', 'squareroot_firstorder_10Percentile', 'squareroot_firstorder_Energy', 'squareroot_firstorder_Entropy', 'squareroot_firstorder_InterquartileRange', 'squareroot_firstorder_MeanAbsoluteDeviation', 'squareroot_firstorder_Mean', 'squareroot_firstorder_Median', 'squareroot_firstorder_Minimum', 'squareroot_firstorder_Range', 'squareroot_firstorder_RobustMeanAbsoluteDeviation', 'squareroot_firstorder_RootMeanSquared', 'squareroot_firstorder_Skewness', 'squareroot_firstorder_TotalEnergy', 'squareroot_firstorder_Variance', 'squareroot_glcm_Autocorrelation', 'squareroot_glcm_JointAverage', 'squareroot_glcm_ClusterShade', 'squareroot_glcm_ClusterTendency', 'squareroot_glcm_Contrast', 'squareroot_glcm_DifferenceAverage', 'squareroot_glcm_DifferenceEntropy', 'squareroot_glcm_DifferenceVariance', 'squareroot_glcm_JointEntropy', 'squareroot_glcm_SumEntropy', 'squareroot_glcm_SumSquares', 'squareroot_glrlm_GrayLevelVariance', 'squareroot_glrlm_HighGrayLevelRunEmphasis', 'squareroot_glrlm_LongRunHighGrayLevelEmphasis', 'squareroot_glrlm_RunEntropy', 'squareroot_glrlm_RunLengthNonUniformity', 'squareroot_glrlm_ShortRunHighGrayLevelEmphasis', 'squareroot_glszm_GrayLevelVariance', 'squareroot_glszm_HighGrayLevelZoneEmphasis', 'squareroot_glszm_LargeAreaHighGrayLevelEmphasis', 'squareroo ...

# %%
# Plotting correlation matrix
fig, axes = plt.subplots(1, 3, figsize=(300, 80))

titles = ['All_features', 'Correlated_features', 'Non_highly_correlated_features']
corr_matrix_l= [df_features_numeric.corr(method='pearson'),
                df_features_numeric[corr_vars].corr(method='pearson'),
                df_features_decorr.iloc[:,1:].corr(method='pearson')] # Remove first column

for i, ax in enumerate(axes):
    sns.heatmap(corr_matrix_l[i], annot=False, cmap='viridis', linewidths=0.5, ax=ax)

    ax.set_title(titles[i], fontsize=150, pad=220)
    ax.set_xticklabels([])
    ax.set_yticklabels([])

plt.tight_layout()
plt.show()

# Save plot
fig_dir= 'Figures/'
fig.savefig(fig_dir + '1_corr_AF_feature_selection_process.pdf', format='pdf', bbox_inches='tight', dpi=200)

# Close figure
plt.close()

# %% [markdown]
# ### **6. Adapt dataframe to merge with clinical data and labels**

# %%
# Add radiomic label (R) and segment label (AF) to all radiomic features
old_new_names_dict= dict([(col_name, 'R_AF_' + col_name) for col_name in df_features_decorr.columns])

# Rename columns
df_features_cleaned= df_features_decorr.rename(columns=old_new_names_dict)

# Extract EPI_CODES
epi_codes= [image_segmentation[:8] for image_segmentation in df_features_cleaned['R_AF_Image_Segmentation']]

# Add EPI_CODE column in first position
df_features_cleaned.insert(loc=0, column='EPI_CODE', value=epi_codes, allow_duplicates=False)

# Remove the old column
df_features_cleaned= df_features_cleaned.drop('R_AF_Image_Segmentation', axis=1)

print(df_features_cleaned.shape)
df_features_cleaned.head()
# Out:
# (99, 479)
#    EPI_CODE  R_AF_original_shape_LeastAxisLength  \
# 0  EPI_0001                             3.023389
# 1  EPI_0002                             2.815211
# 2  EPI_0003                             3.140533
# 3  EPI_0004                             3.097962
# 4  EPI_0005                             2.916515
#
#    R_AF_original_shape_MajorAxisLength  \
# 0                             4.257578
# 1                             4.590630
# 2                             5.315134
# 3                             5.282717
# 4                             6.223457
#
#    R_AF_original_shape_Maximum2DDiameterColumn  \
# 0                                     5.099020
# 1                                     4.472136
# 2                                     5.385165
# 3                                     5.385165
# 4                                     7.071068
#
#    R_AF_original_shape_Maximum2DDiameterRow  \
# 0                                  4.123106
# 1                                  3.605551
# 2                                  4.472136
# 3                                  4.123106
# 4                                  4.472136
#
#    R_AF_original_shape_Maximum2DDiameterSlice  \
# 0                                    5.099020
# 1                                    4.472136
# 2                                    5.385165
# 3                                    5.099020
# 4                                    7.000000
#
#    R_AF_original_shape_Maximum3DDiameter  R_AF_original_shape_MeshVolume  \
# 0                               5.196152                       21.541667
# 1                               4.898979                       17.375000
# 2                               5.477226                       28.458333
# 3                               5.477226                       21.875000
# 4                               7.348469                       34.666667
#
#    R_AF_original_shape_MinorAxisLength  \
# 0                             3.277801
# 1                             3.390659
# 2                             3.458037
# 3                             3.446484
# 4                             4.123412
#
#    R_AF_original_shape_SurfaceVolumeRatio  \
# 0                                2.199027
# 1                                2.823894
# 2                                2.079975
# 3                                2.496766
# 4                                2.023929
#
#    R_AF_original_firstorder_10Percentile  \
# 0                                 1402.0
# 1                                  940.8
# 2                                  890.2
# 3                                 1101.8
# 4                                  742.4
#
#    R_AF_original_firstorder_90Percentile  R_AF_original_firstorder_Energy  \
# 0                                 2206.0                      214809125.0
# 1                                 1974.1                      141359794.0
# 2                                 2098.6                      236998638.0
# 3                                 1953.0                      184152556.0
# 4                                 2019.2                      251594216.0
#
#    R_AF_original_firstorder_Entropy  \
# 0                          4.103910
# 1                          3.754442
# 2                          4.173034
# 3                          4.134336
# 4                          4.771928
#
#    R_AF_original_firstorder_InterquartileRange  \
# 0                                       393.75
# 1                                       737.25
# 2                                       757.00
# 3                                       421.00
# 4                                       750.25
#
#    R_AF_original_firstorder_Kurtosis  R_AF_original_firstorder_Maximum  \
# 0                           3.970625                            2373.0
# 1                           1.672614                            2067.0
# 2                           2.151862                            2200.0
# 3                           3.439090                            2250.0
# 4                           2.439636                            2586.0
#
#    R_AF_original_firstorder_MeanAbsoluteDeviation  \
# 0                                      283.227811
# 1                                      370.355372
# 2                                      395.057851
# 3                                      286.076818
# 4                                      444.640000
#
#    R_AF_original_firstorder_Mean  R_AF_original_firstorder_Minimum  \
# 0                    1852.269231                             787.0
# 1                    1501.363636                             749.0
# 2                    1640.121212                             701.0
# 3                    1585.185185                             573.0
# 4                    1449.600000                             326.0
#
#    R_AF_original_firstorder_Skewness  R_AF_original_glcm_Autocorrelation  \
# 0                          -1.028430                         1029.297679
# 1                          -0.407843                          361.596004
# 2                          -0.730255                          796.333265
# 3                          -0.815126                          929.509632
# 4                          -0.195763                         1104.245323
#
#    R_AF_original_glcm_ClusterProminence  R_AF_original_glcm_ClusterShade  \
# 0                         137670.717781                     -2309.882992
# 1                         138307.199503                       -92.791929
# 2                         179843.780110                     -1560.575045
# 3                         120753.258189                     -1465.812153
# 4                         487150.090691                     -1850.550383
#
#    R_AF_original_glcm_Contrast  R_AF_original_glrlm_GrayLevelNonUniformity  \
# 0                   178.800642                                    1.653136
# 1                   304.213220                                    1.818182
# 2                   338.694128                                    2.006556
# 3                   218.654083                                    1.632584
# 4                   309.042816                                    1.532840
#
#    R_AF_original_glszm_GrayLevelNonUniformity  \
# 0                                    1.190476
# 1                                    1.818182
# 2                                    1.689655
# 3                                    1.416667
# 4                                    1.294118
#
#    R_AF_original_glszm_LargeAreaEmphasis  \
# 0                               1.904762
# 1                               1.000000
# 2                               1.413793
# 3                               1.458333
# 4                               1.529412
#
#    R_AF_original_glszm_SizeZoneNonUniformity  \
# 0                                  15.666667
# 1                                  22.000000
# 2                                  22.103448
# 3                                  20.250000
# 4                                  24.117647
#
#    R_AF_original_gldm_DependenceNonUniformityNormalized  \
# 0                                           0.538462
# 1                                           1.000000
# 2                                           0.632691
# 3                                           0.681756
# 4                                           0.580000
#
#    R_AF_original_gldm_DependenceVariance  R_AF_original_ngtdm_Complexity  \
# 0                               0.390533                     2041.293892
# 1                               0.000000                     2445.963901
# 2                               0.183655                     4065.362712
# 3                               0.430727                     2032.823998
# 4                               0.210000                     6292.923455
#
#    R_AF_original_ngtdm_Contrast  R_AF_original_ngtdm_Strength  \
# 0                      4.334490                     44.510970
# 1                     13.375563                     35.891986
# 2                      9.626154                     37.298595
# 3                      4.654820                     45.840036
# 4                      5.801555                     66.518811
#
#    R_AF_square_firstorder_Entropy  R_AF_square_firstorder_Kurtosis  \
# 0                        4.161978                         2.637697
# 1                        3.749903                         1.611588
# 2                        4.476064                         1.851260
# 3                        4.384517                         2.732978
# 4                        4.653056                         3.023983
#
#    R_AF_square_firstorder_Minimum  R_AF_square_firstorder_Range  \
# 0                      232.845489                   1884.120301
# 1                      222.796267                   1473.982526
# 2                      201.064239                   1779.295827
# 3                      138.477014                   1996.698018
# 4                       41.096674                   2544.903326
#
#    R_AF_square_firstorder_Skewness  R_AF_square_glcm_Autocorrelation  \
# 0                        -0.472600                        935.735057
# 1                        -0.185068                        284.714952
# 2                        -0.440167                        729.857198
# 3                        -0.155754                        743.663884
# 4                         0.608261                        589.856440
#
#    R_AF_square_glcm_ClusterProminence  R_AF_square_glcm_ClusterShade  \
# 0                       204972.271546                   -2087.225375
# 1                       158933.742117                     454.418074
# 2                       304712.602837                   -1194.224932
# 3                       170711.941594                       0.518549
# 4                       518999.733633                    2900.347673
#
#    R_AF_square_glcm_Contrast  R_AF_square_glcm_DifferenceVariance  \
# 0                 242.964283                            63.251218
# 1                 317.228871                            84.037416
# 2                 430.957431                           133.945879
# 3                 264.885949                            78.081896
# 4                 320.027369                           108.767392
#
#    R_AF_square_glrlm_GrayLevelNonUniformity  \
# 0                                  1.654773
# 1                                  2.036963
# 2                                  1.590829
# 3                                  1.360342
# 4                                  1.687179
#
#    R_AF_square_glszm_GrayLevelNonUniformity  \
# 0                                  1.260870
# 1                                  1.421053
# 2                                  1.400000
# 3                                  1.240000
# 4                                  1.514286
#
#    R_AF_square_glszm_LargeAreaEmphasis  \
# 0                             1.478261
# 1                             1.473684
# 2                             1.300000
# 3                             1.240000
# 4                             1.428571
#
#    R_AF_square_glszm_LargeAreaHighGrayLevelEmphasis  \
# 0                                       1539.043478
# 1                                        772.631579
# 2                                       1236.166667
# 3                                        991.680000
# 4                                       1045.285714
#
#    R_AF_square_glszm_SizeZoneNonUniformity  \
# 0                                19.260870
# 1                                13.947368
# 2                                24.600000
# 3                                21.320000
# 4                                26.428571
#
#    R_AF_square_gldm_DependenceNonUniformityNormalized  \
# 0                                           0.677515
# 1                                           0.603306
# 2                                           0.702479
# 3                                           0.747599
# 4                                           0.625000
#
#    R_AF_square_gldm_DependenceVariance  R_AF_square_ngtdm_Complexity  \
# 0                             0.254438                   2929.269884
# 1                             0.198347                   2810.165269
# 2                             0.148760                   5775.866382
# 3                             0.126200                   2899.789908
# 4                             0.187500                   5990.445640
#
#    R_AF_square_ngtdm_Contrast  R_AF_square_ngtdm_Strength  \
# 0                    6.223564                   50.412341
# 1                   12.735892                   40.808707
# 2                    9.290303                   48.939161
# 3                    4.779270                   55.187741
# 4                    6.867110                   65.517165
#
#    R_AF_squareroot_firstorder_90Percentile  \
# 0                              2422.261237
# 1                              2229.447253
# 2                              2264.701923
# 3                              2151.752527
# 4                              2284.951790
#
#    R_AF_squareroot_firstorder_Kurtosis  R_AF_squareroot_firstorder_Maximum  \
# 0                             5.261271                         2512.405222
# 1                             1.790028                         2281.382476
# 2                             2.390930                         2318.792789
# 3                             4.436972                         2309.707774
# 4                             2.902127                         2586.000000
#
#    R_AF_squareroot_glcm_ClusterProminence  \
# 0                            86659.270812
# 1                            94615.837427
# 2                           104935.659278
# 3                            87640.895102
# 4                           478818.363525
#
#    R_AF_squareroot_glrlm_GrayLevelNonUniformity  \
# 0                                      2.066192
# 1                                      2.036963
# 2                                      2.175267
# 3                                      1.848284
# 4                                      1.535700
#
#    R_AF_squareroot_glszm_GrayLevelNonUniformity  \
# 0                                      1.380952
# 1                                      1.421053
# 2                                      1.758621
# 3                                      1.521739
# 4                                      1.342857
#
#    R_AF_squareroot_glszm_LargeAreaEmphasis  \
# 0                                 2.000000
# 1                                 1.473684
# 2                                 1.482759
# 3                                 1.608696
# 4                                 1.428571
#
#    R_AF_squareroot_glszm_SizeZoneNonUniformity  \
# 0                                    15.666667
# 1                                    13.947368
# 2                                    23.482759
# 3                                    17.608696
# 4                                    26.428571
#
#    R_AF_squareroot_gldm_DependenceNonUniformityNormalized  \
# 0                                           0.523669
# 1                                           0.603306
# 2                                           0.654729
# 3                                           0.582990
# 4                                           0.625000
#
#    R_AF_squareroot_ngtdm_Contrast  R_AF_logarithm_firstorder_10Percentile  \
# 0                        3.501532                             2444.099258
# 1                        9.016699                             2201.563110
# 2                        6.015707                             2127.845962
# 3                        3.710827                             2137.337415
# 4                        5.022569                             2175.628808
#
#    R_AF_logarithm_firstorder_90Percentile  R_AF_logarithm_firstorder_Mean  \
# 0                             2596.834303                     2530.182070
# 1                             2439.747779                     2337.929505
# 2                             2396.278215                     2303.504262
# 3                             2311.787993                     2237.493103
# 4                             2504.536918                     2365.588751
#
#    R_AF_logarithm_glrlm_GrayLevelNonUniformity  \
# 0                                     2.143216
# 1                                     1.799201
# 2                                     2.276830
# 3                                     1.923471
# 4                                     1.820611
#
#    R_AF_logarithm_glszm_GrayLevelNonUniformity  \
# 0                                     1.400000
# 1                                     1.571429
# 2                                     1.560000
# 3                                     1.608696
# 4                                     1.470588
#
#    R_AF_logarithm_glszm_LargeAreaEmphasis  \
# 0                                2.200000
# 1                                1.142857
# 2                                2.120000
# 3                                1.608696
# 4                                1.588235
#
#    R_AF_logarithm_glszm_SizeZoneNonUniformity  R_AF_logarithm_ngtdm_Contrast  \
# 0                                   13.300000                       2.400565
# 1                                   19.095238                       6.479913
# 2                                   15.240000                       4.824368
# 3                                   17.608696                       2.885119
# 4                                   25.235294                       5.566221
#
#    R_AF_exponential_firstorder_10Percentile  \
# 0                                 63.870300
# 1                                 18.720217
# 2                                 17.143174
# 3                                 37.010970
# 4                                  9.543739
#
#    R_AF_exponential_firstorder_Entropy  \
# 0                             3.950064
# 1                             3.208987
# 2                             4.104408
# 3                             4.282484
# 4                             3.694588
#
#    R_AF_exponential_firstorder_InterquartileRange  \
# 0                                      337.842272
# 1                                      261.337428
# 2                                      539.497281
# 3                                      317.607063
# 4                                      216.497819
#
#    R_AF_exponential_firstorder_Kurtosis  R_AF_exponential_firstorder_Minimum  \
# 0                              3.598108                            10.311016
# 1                              2.849457                            10.272408
# 2                              2.428877                             9.371125
# 3                              9.518515                             6.540641
# 4                             17.732816                             2.692822
#
#    R_AF_exponential_glcm_ClusterProminence  \
# 0                             2.413802e+05
# 1                             2.954691e+04
# 2                             4.017033e+05
# 3                             6.659569e+05
# 4                             2.579514e+06
#
#    R_AF_exponential_glcm_DifferenceEntropy  \
# 0                                 2.961139
# 1                                 2.082423
# 2                                 3.445284
# 3                                 2.836630
# 4                                 3.407718
#
#    R_AF_exponential_glrlm_GrayLevelNonUniformity  \
# 0                                       1.819093
# 1                                       2.595804
# 2                                       2.420455
# 3                                       1.497863
# 4                                       3.976823
#
#    R_AF_exponential_glrlm_LongRunLowGrayLevelEmphasis  \
# 0                                           0.062416
# 1                                           0.280002
# 2                                           0.208113
# 3                                           0.120684
# 4                                           0.355579
#
#    R_AF_exponential_glszm_GrayLevelNonUniformity  \
# 0                                       1.454545
# 1                                       1.875000
# 2                                       1.965517
# 3                                       1.250000
# 4                                       1.640000
#
#    R_AF_exponential_glszm_LargeAreaEmphasis  \
# 0                                  1.636364
# 1                                  2.875000
# 2                                  1.413793
# 3                                  1.458333
# 4                                  4.640000
#
#    R_AF_exponential_glszm_SizeZoneNonUniformity  \
# 0                                     16.636364
# 1                                     12.500000
# 2                                     22.103448
# 3                                     20.250000
# 4                                     13.800000
#
#    R_AF_exponential_glszm_ZoneEntropy  R_AF_exponential_glszm_ZonePercentage  \
# 0                            4.095795                               0.846154
# 1                            3.280639                               0.727273
# 2                            4.444188                               0.878788
# 3                            4.334963                               0.888889
# 4                            4.403856                               0.625000
#
#    R_AF_exponential_gldm_DependenceEntropy  \
# 0                                 4.161978
# 1                                 3.754442
# 2                                 4.438334
# 3                                 4.384517
# 4                                 4.496439
#
#    R_AF_exponential_gldm_DependenceVariance  R_AF_exponential_ngtdm_Busyness  \
# 0                                  0.289941                         0.080442
# 1                                  1.107438                         0.220297
# 2                                  0.183655                         0.142563
# 3                                  0.246914                         0.047509
# 4                                  1.400000                         0.161301
#
#    R_AF_exponential_ngtdm_Contrast  R_AF_gradient_firstorder_10Percentile  \
# 0                         8.692374                             538.856705
# 1                         5.124807                             474.283328
# 2                        11.287877                             373.885266
# 3                         7.277387                             538.012134
# 4                        22.888533                             432.777887
#
#    R_AF_gradient_firstorder_90Percentile  R_AF_gradient_firstorder_Entropy  \
# 0                            1623.811584                          4.392747
# 1                            1122.312134                          3.481715
# 2                            1537.463672                          4.620152
# 3                            1493.250342                          4.236369
# 4                            1279.662219                          4.665312
#
#    R_AF_gradient_firstorder_InterquartileRange  \
# 0                                   664.607895
# 1                                   306.190598
# 2                                   747.651794
# 3                                   421.130829
# 4                                   482.493622
#
#    R_AF_gradient_firstorder_Kurtosis  R_AF_gradient_firstorder_Maximum  \
# 0                           2.375809                       1767.940186
# 1                           2.129068                       1273.638550
# 2                           2.096296                       1826.135620
# 3                           3.177231                       1891.260132
# 4                           2.225464                       1430.300537
#
#    R_AF_gradient_firstorder_MeanAbsoluteDeviation  \
# 0                                      359.997146
# 1                                      206.525693
# 2                                      367.286199
# 3                                      287.030533
# 4                                      250.648070
#
#    R_AF_gradient_firstorder_Mean  R_AF_gradient_firstorder_Median  \
# 0                    1114.092266                      1117.574341
# 1                     848.179965                       900.428192
# 2                    1003.696399                      1076.117798
# 3                     990.731737                       952.665710
# 4                     827.453975                       837.768738
#
#    R_AF_gradient_firstorder_Minimum  R_AF_gradient_firstorder_Skewness  \
# 0                        162.626099                          -0.508232
# 1                        396.064392                          -0.302852
# 2                        216.032990                          -0.156160
# 3                        396.861450                           0.735542
# 4                        298.148865                           0.185207
#
#    R_AF_gradient_glcm_Autocorrelation  R_AF_gradient_glcm_ClusterProminence  \
# 0                         1002.163492                         399063.285455
# 1                          253.118765                          26805.110404
# 2                          736.146215                         410684.269550
# 3                          453.253954                         300146.445529
# 4                          354.579372                         107820.062075
#
#    R_AF_gradient_glcm_ClusterShade  R_AF_gradient_glcm_DifferenceVariance  \
# 0                     -1325.615978                             121.152396
# 1                      -270.040357                              35.591927
# 2                     -1194.455003                             123.795543
# 3                      2111.257798                             118.895837
# 4                      1047.966879                              55.525102
#
#    R_AF_gradient_glrlm_GrayLevelNonUniformity  \
# 0                                    1.307692
# 1                                    2.021382
# 2                                    1.420455
# 3                                    1.662722
# 4                                    1.743590
#
#    R_AF_gradient_glszm_GrayLevelNonUniformity  \
# 0                                    1.307692
# 1                                    1.285714
# 2                                    1.375000
# 3                                    1.615385
# 4                                    1.666667
#
#    R_AF_gradient_glszm_LargeAreaEmphasis  \
# 0                               1.000000
# 1                               3.000000
# 2                               1.093750
# 3                               1.115385
# 4                               1.076923
#
#    R_AF_gradient_glszm_LargeAreaHighGrayLevelEmphasis  \
# 0                                        1293.653846
# 1                                        1031.000000
# 2                                        1036.562500
# 3                                         614.192308
# 4                                         489.692308
#
#    R_AF_gradient_glszm_SizeZoneNonUniformity  \
# 0                                  26.000000
# 1                                   6.000000
# 2                                  30.062500
# 3                                  24.076923
# 4                                  37.051282
#
#    R_AF_gradient_gldm_DependenceNonUniformityNormalized  \
# 0                                           1.000000
# 1                                           0.371901
# 2                                           0.886134
# 3                                           0.862826
# 4                                           0.905000
#
#    R_AF_gradient_gldm_DependenceVariance  R_AF_gradient_ngtdm_Complexity  \
# 0                               0.000000                     5583.974225
# 1                               0.512397                     1019.340544
# 2                               0.056933                     6862.581149
# 3                               0.068587                     4022.537554
# 4                               0.047500                     3651.431430
#
#    R_AF_gradient_ngtdm_Contrast  \
# 0                     11.530308
# 1                      7.696006
# 2                      8.471353
# 3                      7.955588
# 4                      2.483101
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_10Percentile  \
# 0                                       -932.289856
# 1                                       -754.437561
# 2                                       -879.739722
# 3                                       -761.705103
# 4                                       -645.772955
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_90Percentile  \
# 0                                       -138.323963
# 1                                        -63.211198
# 2                                        -57.695822
# 3                                        -67.774106
# 4                                         98.016230
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_Energy  \
# 0                                6.624916e+06
# 1                                1.019162e+07
# 2                                1.262793e+07
# 3                                1.194052e+07
# 4                                2.272490e+07
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_InterquartileRange  \
# 0                                         473.113304
# 1                                         480.566673
# 2                                         453.719162
# 3                                         369.368172
# 4                                         487.583407
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_Kurtosis  \
# 0                                      2.275274
# 1                                      1.652926
# 2                                      1.980788
# 3                                      2.631347
# 4                                      2.487503
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_Maximum  \
# 0                                    72.028061
# 1                                    98.113831
# 2                                    86.273560
# 3                                   253.134766
# 4                                   467.031647
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation  \
# 0                                         269.682086
# 1                                         248.870229
# 2                                         262.949437
# 3                                         225.917047
# 4                                         245.347198
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_Mean  \
# 0                               -612.077043
# 1                               -376.802422
# 2                               -464.422530
# 3                               -395.996173
# 4                               -303.289686
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_Minimum  \
# 0                                 -1088.922241
# 1                                  -784.226196
# 2                                 -1100.893433
# 3                                  -818.625183
# 4                                  -703.172058
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_Range  \
# 0                                1160.950302
# 1                                 882.340027
# 2                                1187.166992
# 3                                1071.759949
# 4                                1170.203705
#
#    R_AF_log-sigma-1-0-mm-3D_firstorder_Skewness  \
# 0                                      0.601306
# 1                                     -0.135813
# 2                                     -0.115512
# 3                                      0.379812
# 4                                      0.549876
#
#    R_AF_log-sigma-1-0-mm-3D_glcm_Autocorrelation  \
# 0                                     796.475075
# 1                                     836.759241
# 2                                    1721.067654
# 3                                     644.353600
# 4                                     727.632635
#
#    R_AF_log-sigma-1-0-mm-3D_glcm_ClusterShade  \
# 0                                17749.964793
# 1                                 4962.036992
# 2                                 8394.175167
# 3                                 5892.012822
# 4                                19300.321000
#
#    R_AF_log-sigma-1-0-mm-3D_glcm_Contrast  \
# 0                              603.447616
# 1                              267.837113
# 2                              567.420306
# 3                              467.487710
# 4                              336.072068
#
#    R_AF_log-sigma-1-0-mm-3D_glcm_Correlation  \
# 0                                   0.130973
# 1                                   0.425419
# 2                                   0.329655
# 3                                   0.097444
# 4                                   0.457913
#
#    R_AF_log-sigma-1-0-mm-3D_glcm_DifferenceVariance  \
# 0                                        193.783749
# 1                                         66.920591
# 2                                        189.713581
# 3                                        108.739726
# 4                                        114.117395
#
#    R_AF_log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformity  \
# 0                                           1.225325
# 1                                           1.181818
# 2                                           1.518357
# 3                                           1.498865
# 4                                           1.562525
#
#    R_AF_log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformity  \
# 0                                           1.160000
# 1                                           1.181818
# 2                                           1.214286
# 3                                           1.250000
# 4                                           1.277778
#
#    R_AF_log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis  \
# 0                                          1.120000
# 1                                          1.000000
# 2                                          1.607143
# 3                                          1.375000
# 4                                          1.388889
#
#    R_AF_log-sigma-1-0-mm-3D_glszm_SizeZoneNonUniformity  \
# 0                                          23.080000
# 1                                          22.000000
# 2                                          20.928571
# 3                                          18.750000
# 4                                          30.388889
#
#    R_AF_log-sigma-1-0-mm-3D_ngtdm_Complexity  \
# 0                                8518.836622
# 1                                3283.721579
# 2                                8342.048692
# 3                                6873.461661
# 4                                7282.489526
#
#    R_AF_log-sigma-1-0-mm-3D_ngtdm_Contrast  \
# 0                                23.661484
# 1                                12.932185
# 2                                17.672475
# 3                                20.625347
# 4                                 7.419464
#
#    R_AF_log-sigma-1-0-mm-3D_ngtdm_Strength  \
# 0                               128.796019
# 1                               161.152217
# 2                               105.390417
# 3                                92.946678
# 4                               131.249835
#
#    R_AF_log-sigma-2-0-mm-3D_firstorder_10Percentile  \
# 0                                       -575.503967
# 1                                       -299.049902
# 2                                       -469.785138
# 3                                       -348.597302
# 4                                       -483.673145
#
#    R_AF_log-sigma-2-0-mm-3D_firstorder_90Percentile  \
# 0                                        -82.333221
# 1                                        149.264659
# 2                                          1.480955
# 3                                        146.980328
# 4                                        405.013492
#
#    R_AF_log-sigma-2-0-mm-3D_firstorder_Entropy  \
# 0                                     4.286790
# 1                                     3.823068
# 2                                     4.331977
# 3                                     4.282484
# 4                                     4.603056
#
#    R_AF_log-sigma-2-0-mm-3D_firstorder_InterquartileRange  \
# 0                                         228.169907
# 1                                         255.576931
# 2                                         291.766754
# 3                                         334.782089
# 4                                         404.565914
#
#    R_AF_log-sigma-2-0-mm-3D_firstorder_Kurtosis  \
# 0                                      3.592246
# 1                                      2.378224
# 2                                      1.942243
# 3                                      2.766335
# 4                                      2.475884
#
#    R_AF_log-sigma-2-0-mm-3D_firstorder_Maximum  \
# 0                                   275.546783
# 1                                   243.367950
# 2                                    65.378128
# 3                                   424.049255
# 4                                   558.584290
#
#    R_AF_log-sigma-2-0-mm-3D_firstorder_Mean  \
# 0                               -338.336541
# 1                               -108.588559
# 2                               -256.176314
# 3                               -100.474343
# 4                               -150.960695
#
#    R_AF_log-sigma-2-0-mm-3D_firstorder_Range  \
# 0                                 918.002716
# 1                                 563.249237
# 2                                 610.630814
# 3                                 808.585266
# 4                                1132.879333
#
#    R_AF_log-sigma-2-0-mm-3D_firstorder_Skewness  \
# 0                                      0.919823
# 1                                      0.557869
# 2                                      0.155794
# 3                                      0.689221
# 4                                      0.770126
#
#    R_AF_log-sigma-2-0-mm-3D_glcm_Autocorrelation  \
# 0                                     377.348030
# 1                                     216.482085
# 2                                     392.840565
# 3                                     327.822969
# 4                                     885.075910
#
#    R_AF_log-sigma-2-0-mm-3D_glcm_ClusterProminence  \
# 0                                     6.132334e+05
# 1                                     2.415642e+05
# 2                                     2.046777e+05
# 3                                     4.168531e+05
# 4                                     5.140465e+06
#
#    R_AF_log-sigma-2-0-mm-3D_glcm_Contrast  \
# 0                              205.121506
# 1                              134.928438
# 2                              181.791162
# 3                              217.887095
# 4                              227.509106
#
#    R_AF_log-sigma-2-0-mm-3D_glcm_Correlation  \
# 0                                   0.257797
# 1                                   0.211704
# 2                                   0.270826
# 3                                   0.243399
# 4                                   0.654209
#
#    R_AF_log-sigma-2-0-mm-3D_glcm_DifferenceVariance  \
# 0                                         57.575904
# 1                                         23.780139
# 2                                         41.664525
# 3                                         39.422981
# 4                                         54.284942
#
#    R_AF_log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformity  \
# 0                                           1.445917
# 1                                           1.729071
# 2                                           1.756993
# 3                                           1.483235
# 4                                           1.805382
#
#    R_AF_log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformity  \
# 0                                           1.250000
# 1                                           1.315789
# 2                                           1.307692
# 3                                           1.250000
# 4                                           1.363636
#
#    R_AF_log-sigma-2-0-mm-3D_glszm_LargeAreaEmphasis  \
# 0                                          1.250000
# 1                                          1.789474
# 2                                          1.807692
# 3                                          1.458333
# 4                                          1.878788
#
#    R_AF_log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformity  \
# 0                                          20.333333
# 1                                          17.105263
# 2                                          15.769231
# 3                                          20.250000
# 4                                          25.666667
#
#    R_AF_log-sigma-2-0-mm-3D_gldm_DependenceNonUniformityNormalized  \
# 0                                           0.739645
# 1                                           0.685950
# 2                                           0.511478
# 3                                           0.681756
# 4                                           0.571250
#
#    R_AF_log-sigma-2-0-mm-3D_gldm_DependenceVariance  \
# 0                                          0.130178
# 1                                          0.975207
# 2                                          0.244261
# 3                                          0.430727
# 4                                          0.377500
#
#    R_AF_log-sigma-2-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                           0.058601
# 1                                           0.346696
# 2                                           0.051549
# 3                                           0.154515
# 4                                           0.081138
#
#    R_AF_log-sigma-2-0-mm-3D_ngtdm_Complexity  \
# 0                                3184.268810
# 1                                1421.846614
# 2                                2407.873101
# 3                                3242.428847
# 4                                4575.481400
#
#    R_AF_log-sigma-2-0-mm-3D_ngtdm_Contrast  \
# 0                                 7.630629
# 1                                 6.102375
# 2                                 3.839164
# 3                                 7.564392
# 4                                 7.959664
#
#    R_AF_log-sigma-3-0-mm-3D_firstorder_10Percentile  \
# 0                                       -375.150177
# 1                                       -332.535220
# 2                                       -509.185944
# 3                                       -256.631677
# 4                                       -389.357535
#
#    R_AF_log-sigma-3-0-mm-3D_firstorder_90Percentile  \
# 0                                        -10.461143
# 1                                        154.904684
# 2                                         -5.263550
# 3                                        222.119260
# 4                                         10.911570
#
#    R_AF_log-sigma-3-0-mm-3D_firstorder_Energy  \
# 0                                1.671570e+07
# 1                                1.962332e+07
# 2                                1.925997e+07
# 3                                2.604750e+07
# 4                                2.916432e+07
#
#    R_AF_log-sigma-3-0-mm-3D_firstorder_Entropy  \
# 0                                     4.209867
# 1                                     4.004886
# 2                                     4.476064
# 3                                     4.384517
# 4                                     4.615312
#
#    R_AF_log-sigma-3-0-mm-3D_firstorder_InterquartileRange  \
# 0                                         217.550291
# 1                                         345.063883
# 2                                         332.460129
# 3                                         231.605099
# 4                                         216.562994
#
#    R_AF_log-sigma-3-0-mm-3D_firstorder_Kurtosis  \
# 0                                      2.301812
# 1                                      1.746743
# 2                                      2.131389
# 3                                      2.203403
# 4                                      1.909627
#
#    R_AF_log-sigma-3-0-mm-3D_firstorder_Maximum  \
# 0                                   106.373276
# 1                                   262.197205
# 2                                   175.987930
# 3                                   321.764282
# 4                                   122.955673
#
#    R_AF_log-sigma-3-0-mm-3D_firstorder_Range  \
# 0                                 560.796249
# 1                                 608.438110
# 2                                 720.057877
# 3                                 696.122131
# 4                                 552.450729
#
#    R_AF_log-sigma-3-0-mm-3D_firstorder_Skewness  \
# 0                                      0.489344
# 1                                      0.046286
# 2                                      0.388972
# 3                                      0.244942
# 4                                     -0.250800
#
#    R_AF_log-sigma-3-0-mm-3D_glcm_Autocorrelation  \
# 0                                     362.388423
# 1                                     554.488511
# 2                                     526.142899
# 3                                     607.228104
# 4                                     351.604264
#
#    R_AF_log-sigma-3-0-mm-3D_glcm_ClusterShade  \
# 0                                 1173.813721
# 1                                -4030.191834
# 2                                  689.937458
# 3                                -1019.971123
# 4                                 -690.516536
#
#    R_AF_log-sigma-3-0-mm-3D_glcm_Contrast  \
# 0                              129.762599
# 1                              141.399550
# 2                              134.508871
# 3                              109.528081
# 4                              107.089223
#
#    R_AF_log-sigma-3-0-mm-3D_glcm_DifferenceVariance  \
# 0                                         17.616894
# 1                                         13.589467
# 2                                         20.865895
# 3                                         21.487514
# 4                                         17.258169
#
#    R_AF_log-sigma-3-0-mm-3D_glrlm_GrayLevelNonUniformity  \
# 0                                           1.509448
# 1                                           1.436996
# 2                                           1.578234
# 3                                           1.355520
# 4                                           1.760516
#
# ...
#
#    R_AF_lbp-3D-m1_ngtdm_Complexity  R_AF_lbp-3D-m1_ngtdm_Contrast  \
# 0                       130.409733                       0.452334
# 1                       257.006196                       0.885442
# 2                       373.892746                       0.872101
# 3                       107.514493                       0.333527
# 4                       461.841712                       0.987447
#
#    R_AF_lbp-3D-m1_ngtdm_Strength  R_AF_lbp-3D-m2_firstorder_10Percentile  \
# 0                       7.805355                                3.227637
# 1                      10.654687                                1.546441
# 2                       9.104120                                1.665260
# 3                       6.130759                                1.748752
# 4                       7.129237                                1.468838
#
#    R_AF_lbp-3D-m2_firstorder_90Percentile  R_AF_lbp-3D-m2_firstorder_Entropy  \
# 0                               11.257262                           3.286790
# 1                               10.255808                           3.390805
# 2                               12.485714                           3.604704
# 3                                9.257811                           3.101955
# 4                               13.151762                           3.764911
#
#    R_AF_lbp-3D-m2_firstorder_InterquartileRange  \
# 0                                      4.355909
# 1                                      4.684323
# 2                                      6.166049
# 3                                      4.424607
# 4                                      6.937117
#
#    R_AF_lbp-3D-m2_firstorder_Kurtosis  R_AF_lbp-3D-m2_firstorder_Maximum  \
# 0                            2.335264                          13.420733
# 1                            2.035384                          12.101362
# 2                            1.919885                          15.569576
# 3                            2.004999                          10.564296
# 4                            1.945875                          15.180746
#
#    R_AF_lbp-3D-m2_firstorder_MeanAbsoluteDeviation  \
# 0                                         2.567947
# 1                                         2.815949
# 2                                         3.502933
# 3                                         2.263347
# 4                                         3.747995
#
#    R_AF_lbp-3D-m2_firstorder_Median  R_AF_lbp-3D-m2_firstorder_Skewness  \
# 0                          7.433027                            0.083304
# 1                          5.908272                            0.179499
# 2                          7.748481                            0.053397
# 3                          5.289950                            0.214543
# 4                          7.376414                           -0.140777
#
#    R_AF_lbp-3D-m2_glcm_Autocorrelation  R_AF_lbp-3D-m2_glcm_ClusterProminence  \
# 0                            47.491256                             985.179177
# 1                            54.304462                             895.623287
# 2                            43.469507                            1864.144689
# 3                            25.256023                             476.231089
# 4                            75.004218                            2774.472198
#
#    R_AF_lbp-3D-m2_glcm_ClusterShade  R_AF_lbp-3D-m2_glcm_Contrast  \
# 0                          1.734913                     20.576486
# 1                         -6.850155                     26.115218
# 2                         -0.317265                     32.700417
# 3                         21.378305                     15.763595
# 4                         10.193385                     38.393679
#
#    R_AF_lbp-3D-m2_glcm_DifferenceVariance  \
# 0                                6.398792
# 1                                6.523826
# 2                                9.008684
# 3                                4.361360
# 4                               12.243741
#
#    R_AF_lbp-3D-m2_glrlm_GrayLevelNonUniformity  \
# 0                                     2.839606
# 1                                     2.282384
# 2                                     2.931607
# 3                                     3.187103
# 4                                     3.274209
#
#    R_AF_lbp-3D-m2_glrlm_HighGrayLevelRunEmphasis  \
# 0                                      54.984872
# 1                                      51.062371
# 2                                      64.748188
# 3                                      32.049200
# 4                                      88.867418
#
#    R_AF_lbp-3D-m2_glszm_GrayLevelNonUniformity  \
# 0                                     1.947368
# 1                                     1.588235
# 2                                     2.000000
# 3                                     2.125000
# 4                                     2.000000
#
#    R_AF_lbp-3D-m2_glszm_LargeAreaEmphasis  \
# 0                                2.315789
# 1                                2.117647
# 2                                2.208333
# 3                                3.687500
# 4                                3.142857
#
#    R_AF_lbp-3D-m2_glszm_LargeAreaHighGrayLevelEmphasis  \
# 0                                         105.315789
# 1                                         128.411765
# 2                                         121.416667
# 3                                         126.312500
# 4                                         245.000000
#
#    R_AF_lbp-3D-m2_glszm_LargeAreaLowGrayLevelEmphasis  \
# 0                                           0.301669
# 1                                           0.189109
# 2                                           0.485038
# 3                                           0.540141
# 4                                           0.185705
#
#    R_AF_lbp-3D-m2_glszm_SizeZoneNonUniformity  \
# 0                                   11.000000
# 1                                   11.823529
# 2                                   12.750000
# 3                                    6.375000
# 4                                   17.785714
#
#    R_AF_lbp-3D-m2_glszm_ZoneEntropy  R_AF_lbp-3D-m2_gldm_DependenceVariance  \
# 0                          3.826875                                0.544379
# 1                          3.734522                                0.611570
# 2                          4.168296                                0.308540
# 3                          3.452820                                0.702332
# 4                          4.137538                                0.987500
#
#    R_AF_lbp-3D-m2_ngtdm_Complexity  R_AF_lbp-3D-m2_ngtdm_Contrast  \
# 0                       140.691828                       0.496596
# 1                       175.191763                       0.530925
# 2                       317.623334                       0.668167
# 3                        87.579720                       0.556445
# 4                       396.889619                       0.619136
#
#    R_AF_lbp-3D-m2_ngtdm_Strength  R_AF_lbp-3D-k_firstorder_90Percentile  \
# 0                       7.358706                              -0.032774
# 1                       8.752815                              -0.208885
# 2                       7.315173                              -0.234738
# 3                       4.474568                              -0.228768
# 4                       8.066073                               0.144447
#
#    R_AF_lbp-3D-k_firstorder_Entropy  \
# 0                          1.495632
# 1                          0.937301
# 2                          1.211294
# 3                          1.086049
# 4                          1.469973
#
#    R_AF_lbp-3D-k_firstorder_InterquartileRange  \
# 0                                     0.706317
# 1                                     0.417137
# 2                                     0.696911
# 3                                     0.661901
# 4                                     0.653242
#
#    R_AF_lbp-3D-k_firstorder_Kurtosis  R_AF_lbp-3D-k_firstorder_Maximum  \
# 0                           8.133951                          2.168943
# 1                           2.883164                          0.109190
# 2                           2.420792                          0.248114
# 3                           2.579134                          0.312413
# 4                           3.545297                          1.003941
#
#    R_AF_lbp-3D-k_firstorder_Skewness  R_AF_lbp-3D-k_glcm_Autocorrelation  \
# 0                           2.123311                            3.364397
# 1                           0.529298                            3.498568
# 2                           0.339641                            3.261496
# 3                           0.257841                            2.984317
# 4                           1.002410                            4.137359
#
#    R_AF_lbp-3D-k_glcm_ClusterProminence  R_AF_lbp-3D-k_glcm_DifferenceEntropy  \
# 0                             10.732151                              1.533394
# 1                              0.540668                              0.856022
# 2                              1.321926                              1.109272
# 3                              0.555040                              0.913522
# 4                              2.748496                              1.353390
#
#    R_AF_lbp-3D-k_glrlm_HighGrayLevelRunEmphasis  \
# 0                                      3.878178
# 1                                      3.649697
# 2                                      3.291468
# 3                                      3.254912
# 4                                      4.440570
#
#    R_AF_lbp-3D-k_glrlm_LongRunEmphasis  \
# 0                             1.564837
# 1                             1.782304
# 2                             1.901768
# 3                             1.706201
# 4                             1.820483
#
#    R_AF_lbp-3D-k_glrlm_LongRunHighGrayLevelEmphasis  \
# 0                                          5.351499
# 1                                          6.627089
# 2                                          6.356402
# 3                                          5.742757
# 4                                          7.767071
#
#    R_AF_lbp-3D-k_glrlm_RunEntropy  R_AF_lbp-3D-k_glrlm_RunLengthNonUniformity  \
# 0                        2.083764                                   16.878040
# 1                        1.694109                                   12.581692
# 2                        2.004199                                   18.178672
# 3                        1.775706                                   16.100860
# 4                        2.219591                                   22.406290
#
#    R_AF_lbp-3D-k_glszm_GrayLevelNonUniformity  \
# 0                                    1.666667
# 1                                    1.000000
# 2                                    1.500000
# 3                                    1.500000
# 4                                    2.000000
#
#    R_AF_lbp-3D-k_glszm_GrayLevelVariance  \
# 0                               1.916667
# 1                               0.666667
# 2                               0.687500
# 3                               0.687500
# 4                               1.333333
#
#    R_AF_lbp-3D-k_glszm_HighGrayLevelZoneEmphasis  \
# 0                                       8.166667
# 1                                       4.666667
# 2                                       3.750000
# 3                                       3.750000
# 4                                       5.333333
#
#    R_AF_lbp-3D-k_glszm_LargeAreaEmphasis  \
# 0                              41.333333
# 1                             102.000000
# 2                             126.250000
# 3                              89.750000
# 4                             108.000000
#
#    R_AF_lbp-3D-k_glszm_LargeAreaLowGrayLevelEmphasis  \
# 0                                          28.377037
# 1                                          29.453704
# 2                                          50.361111
# 3                                          28.777778
# 4                                          30.510417
#
#    R_AF_lbp-3D-k_glszm_SizeZoneNonUniformity  \
# 0                                   3.000000
# 1                                   1.000000
# 2                                   1.000000
# 3                                   1.000000
# 4                                   1.333333
#
#    R_AF_lbp-3D-k_glszm_SmallAreaEmphasis  \
# 0                               0.669491
# 1                               0.355320
# 2                               0.315625
# 3                               0.288549
# 4                               0.363438
#
#    R_AF_lbp-3D-k_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                           7.341157
# 1                                           3.025447
# 2                                           0.817500
# 3                                           2.290864
# 4                                           2.901343
#
#    R_AF_lbp-3D-k_glszm_SmallAreaLowGrayLevelEmphasis  \
# 0                                           0.211944
# 1                                           0.058159
# 2                                           0.259601
# 3                                           0.065748
# 4                                           0.202855
#
#    R_AF_lbp-3D-k_glszm_ZoneEntropy  R_AF_lbp-3D-k_glszm_ZoneVariance  \
# 0                         2.251629                         22.555556
# 1                         1.584963                         48.222222
# 2                         2.000000                         58.187500
# 3                         2.000000                         44.187500
# 4                         2.584963                         63.555556
#
#    R_AF_lbp-3D-k_gldm_DependenceEntropy  \
# 0                              3.609496
# 1                              3.265583
# 2                              3.801377
# 3                              3.661933
# 4                              3.702656
#
#    R_AF_lbp-3D-k_gldm_DependenceNonUniformity  \
# 0                                    4.384615
# 1                                    2.727273
# 2                                    4.515152
# 3                                    3.222222
# 4                                    4.600000
#
#    R_AF_lbp-3D-k_gldm_DependenceVariance  \
# 0                               5.213018
# 1                               8.652893
# 2                               7.415978
# 3                               7.654321
# 4                               8.640000
#
#    R_AF_lbp-3D-k_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                          15.010085
# 1                                          11.243687
# 2                                          17.345118
# 3                                          12.318930
# 4                                          12.140451
#
#    R_AF_lbp-3D-k_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           1.769625
# 1                                           0.546965
# 2                                           0.243797
# 3                                           0.495049
# 4                                           0.629002
#
#    R_AF_lbp-3D-k_ngtdm_Busyness  R_AF_lbp-3D-k_ngtdm_Strength
# 0                      1.515360                      1.871021
# 1                      0.508064                      0.730429
# 2                      1.118533                      0.488941
# 3                      1.046149                      0.485882
# 4                      0.652653                      0.843652

# %% [markdown]
# ### **7. Save Radiomic features cleaned**

# %%
# Save data
save_path= 'Databases/'

df_features_cleaned.to_excel(save_path + '5_2_df_radiomics_AF_tuned_final_features_cleaned.xlsx')
df_features_cleaned.to_csv(save_path + '5_2_df_radiomics_AF_tuned_final_features_cleaned.csv')
df_features_cleaned.to_feather(save_path + '5_2_df_radiomics_AF_tuned_final_features_cleaned.feather')
